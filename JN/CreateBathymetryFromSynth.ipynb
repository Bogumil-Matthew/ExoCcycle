# %% [markdown]
# # CreateBathymetryFromSynth
#
# This jupyter-notebook is used to show how ExoCcycle classes, functions, and methods are used to generate synthetic bathymetry models (as shown) and carbon cycle model parameters.

# %%
# Import necessary libraries
import ExoCcycle as EC
import matplotlib as mpl
import numpy as np
import os

# Define an input directory dictionary containing all necessary
# directories.
directories = {"paleoDEMs":"/home/bogumil/Documents/data/Scotese_Wright_2018_Maps_1-88_1degX1deg_PaleoDEMS_nc/Scotese_Wright_2018_Maps_1-88_1degX1deg_PaleoDEMS_nc_v2"};

# Create bathymetry object for creating synthetic bathymetry models. 
SynthBathy = EC.Bathymetry.BathySynthBogumil24(optSynthModel = 'Model1',
                                               ModelName='myModel')

# Create synthetic bathymetries and Ccycle parameters
SynthBathy.makeSynthModels()

# Save synthetic bathymetrues and Cycle parameters
SynthBathy.saveSynthModels(verbose=False)
